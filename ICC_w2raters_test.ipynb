# %% [markdown]
# <a href="https://colab.research.google.com/github/daonly/personal/blob/main/ICC_w2raters_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pingouin
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.6/198.6 KB 3.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7048 sha256=e1472406c21152b172a5834b7a4d1486e75fa6724620a3569d6e24717448f66f
#   Stored in directory: /root/.cache/pip/wheels/04/bb/0d/2d02ec45f29c48d6192476bfb59c5a0e64b605e7212374dd15
# Successfully built littleutils
# ...

# %%
import pandas as pd

df = pd.DataFrame({'exam': [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6,
                            1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6],
                   'judge': ['A', 'A', 'A', 'A', 'A', 'A',
                             'B', 'B', 'B', 'B', 'B', 'B',
                             'A', 'A', 'A', 'A', 'A', 'A',
                             'B', 'B', 'B', 'B', 'B', 'B'],
                   'rating': [1, 1, 3, 6, 6, 7, 2, 3, 8, 4, 5, 5,
                              0, 4, 1, 5, 5, 6, 1, 2, 3, 3, 6, 4]})

import pingouin as pg

icc = pg.intraclass_corr(data=df, targets='exam', raters='judge', ratings='rating')

icc.set_index('Type')
# Out:
#                    Description       ICC         F  df1  df2      pval  \
# Type
# ICC1    Single raters absolute  0.562307  3.569412    5    6  0.076484
# ICC2      Single random raters  0.542519  2.980354    5    5  0.127949
# ICC3       Single fixed raters  0.497532  2.980354    5    5  0.127949
# ICC1k  Average raters absolute  0.719842  3.569412    5    6  0.076484
# ICC2k    Average random raters  0.703419  2.980354    5    5  0.127949
# ICC3k     Average fixed raters  0.664469  2.980354    5    5  0.127949
#
#                CI95%
# Type
# ICC1   [-0.25, 0.92]
# ICC2   [-0.53, 0.92]
# ICC3   [-0.41, 0.91]
# ICC1k  [-0.68, 0.96]
# ICC2k   [-2.3, 0.96]
# ICC3k   [-1.4, 0.95]
